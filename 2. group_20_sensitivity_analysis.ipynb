# %% [markdown]
# # Sensitivity Analysis

# %% [markdown]
# This notebook performs sesitivity analysis to identify the uncertainities influencing the outcomes of interest. These uncertainities than will be used for formulating scenarios for policy (levers) samping in next step.
#
# In previous analysis, an open exploration was performed to understand the prospect damage if no steps towards flood protectins are taken. The analysis marked dike failure as the biggest threat and Zutphen as the most vulnerable region.
#
#
# Gelderland province priritize the safety of its residents. Thus, the focus of this analysis was set to identify the uncertainities influencing the casualties in the region.

# %%
from __future__ import (unicode_literals, print_function, absolute_import, division)
from ema_workbench import (Model, MultiprocessingEvaluator, Policy, Scenario,SequentialEvaluator)
from ema_workbench.em_framework.evaluators import perform_experiments
from ema_workbench.em_framework.samplers import sample_uncertainties
from ema_workbench.util import ema_logging
ema_logging.log_to_stderr(ema_logging.INFO)
import time
from problem_formulation import get_model_for_problem_formulation
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy as sp
from ema_workbench.em_framework.evaluators import LHS, SOBOL, MORRIS
from ema_workbench.analysis import feature_scoring
from ema_workbench.analysis.scenario_discovery_util import RuleInductionType
from ema_workbench.em_framework.salib_samplers import get_SALib_problem
from SALib.analyze import sobol
import copy
from ema_workbench import save_results
from ema_workbench import load_results

# %% [markdown]
# ## Uncertainties Sampling

# %% [markdown]
# The scope of this analysis is broader by design and results from other two provinces are also taken into the account. Gelderland is an upstream province and every policy intervention upstream affects the downstream provinces. Thus, results from a holistic sensitivity analysis will result in key uncertainities influencing the entire stream.
#
# Selected probelm formulation ---> 3

# %%
dike_model, planning_steps = get_model_for_problem_formulation(3)

# %%
# Visulaize model uncertainties laong with its lower boundary, upper boundary,and types (RealParameter/IntegerParameter/CategoricalParameter)
for unc in dike_model.uncertainties:
    print(repr(unc))

uncertainties = dike_model.uncertainties

uncertainties = copy.deepcopy(dike_model.uncertainties)
# Out:
# CategoricalParameter('discount rate 0', [0, 1, 2, 3])
# CategoricalParameter('discount rate 1', [0, 1, 2, 3])
# CategoricalParameter('discount rate 2', [0, 1, 2, 3])
# IntegerParameter('A.0_ID flood wave shape', 0, 132)
# RealParameter('A.1_Bmax', 30, 350)
# RealParameter('A.1_pfail', 0, 1)
# CategoricalParameter('A.1_Brate', [0, 1, 2])
# RealParameter('A.2_Bmax', 30, 350)
# RealParameter('A.2_pfail', 0, 1)
# CategoricalParameter('A.2_Brate', [0, 1, 2])
# RealParameter('A.3_Bmax', 30, 350)
# RealParameter('A.3_pfail', 0, 1)
# CategoricalParameter('A.3_Brate', [0, 1, 2])
# RealParameter('A.4_Bmax', 30, 350)
# RealParameter('A.4_pfail', 0, 1)
# CategoricalParameter('A.4_Brate', [0, 1, 2])
# RealParameter('A.5_Bmax', 30, 350)
# RealParameter('A.5_pfail', 0, 1)
# CategoricalParameter('A.5_Brate', [0, 1, 2])

# %% [markdown]
# As shown above, the model has `19 Uncertainties`.
# ___
#
# Sobol Analysis is selected for Sensitivity Analysis because
#
#
# 1. dike_model is a non-linear model and Sobol Analysis is compatible with non-liner models.
# 1. Sobol is highly accurate and a gold standard for global Sensitivity analysis.
# 1. The number of experimets are well within the range of Sobol Analysis (i.e >1000(k+2) = 21000).
#
# ___
#
# Sobol analysis requires N(2k+2) samples, where N is a baseline number of experiments required to cover the uncertainties (let's also assume 1000 in this case) and k is the number of uncertainties. We have `k = 19 uncertainties`, so we'll have `1000 * (19*2 + 2) = 40,000` experiments in total.

# %%
# Set problem for salib by passing all the model uncertainities
problem = get_SALib_problem(uncertainties)
print(problem)
# Out:
# {'num_vars': 19, 'names': ['A.0_ID flood wave shape', 'A.1_Bmax', 'A.1_Brate', 'A.1_pfail', 'A.2_Bmax', 'A.2_Brate', 'A.2_pfail', 'A.3_Bmax', 'A.3_Brate', 'A.3_pfail', 'A.4_Bmax', 'A.4_Brate', 'A.4_pfail', 'A.5_Bmax', 'A.5_Brate', 'A.5_pfail', 'discount rate 0', 'discount rate 1', 'discount rate 2'], 'bounds': [(0, 133), (30, 350), (0, 3), (0, 1), (30, 350), (0, 3), (0, 1), (30, 350), (0, 3), (0, 1), (30, 350), (0, 3), (0, 1), (30, 350), (0, 3), (0, 1), (0, 4), (0, 4), (0, 4)]}

# %% [markdown]
# `CAUTION`
# > 'UNCOMMENT FOLLOWING CODE WHEN RUNNING FOR THE FIRST TIME - 40K SCENARIOS TOOK ME 10+ HOURS TO RUN'

# %%
# n_exp = 1000
# with MultiprocessingEvaluator(dike_model) as evaluator:
#     experiments_sobol, outcomes_sobol = evaluator.perform_experiments(scenarios=1000,uncertainty_sampling=SOBOL,policies=1
#                             )

# %%
# experiments_sobol

# %%
# pd.DataFrame.from_dict(outcomes_sobol)

# %% [markdown]
# Loading experiments results from above run

# %%
# save_results((experiments_sobol, outcomes_sobol), 'data_processed/sensitivty_analysis/sobol_uncertainties_sampling.tar.gz')

# %%
experiments_loaded, outcomes_loaded = load_results('data_processed/sensitivty_analysis/sobol_uncertainties_sampling.tar.gz')
# Out:
# [MainProcess/INFO] results loaded succesfully from /Users/anmolsoni/Documents/Documents – Anmol’s MacBook Air/EPA1361/Assignments/epa_1361/final assignment/sobol_uncertainties_sampling.tar.gz

# %%
experiments_loaded
# Out:
#        A.0_ID flood wave shape   A.1_Bmax A.1_Brate  A.1_pfail   A.2_Bmax  \
# 0                          0.0  150.46875       1.5   0.486816  208.28125
# 1                         46.0  150.46875       1.5   0.486816  208.28125
# 2                          0.0  197.96875       1.5   0.486816  208.28125
# 3                          0.0  150.46875       1.0   0.486816  208.28125
# 4                          0.0  150.46875       1.5   0.825684  208.28125
# ...                        ...        ...       ...        ...        ...
# 39995                     42.0  294.53125       1.0   0.687988  303.28125
# 39996                     42.0  294.53125       1.0   0.687988  303.28125
# 39997                     42.0  294.53125       1.0   0.687988  303.28125
# 39998                     42.0  294.53125       1.0   0.687988  303.28125
# 39999                     42.0  294.53125       1.0   0.687988  303.28125
#
#       A.2_Brate  A.2_pfail   A.3_Bmax A.3_Brate  A.3_pfail  ...  \
# 0          10.0   0.241699  217.96875      10.0   0.671387  ...
# 1          10.0   0.241699  217.96875      10.0   0.671387  ...
# 2          10.0   0.241699  217.96875      10.0   0.671387  ...
# 3          10.0   0.241699  217.96875      10.0   0.671387  ...
# 4          10.0   0.241699  217.96875      10.0   0.671387  ...
# ...         ...        ...        ...       ...        ...  ...
# 39995       1.0   0.413574  341.09375      10.0   0.062012  ...
# 39996       1.0   0.413574  341.09375      10.0   0.062012  ...
# 39997       1.0   0.413574  341.09375      10.0   0.062012  ...
# 39998       1.0   0.413574  341.09375      10.0   0.062012  ...
# 39999       1.0   0.413574  341.09375      10.0   0.062012  ...
#
#        A.4_DikeIncrease 0 A.4_DikeIncrease 1  A.4_DikeIncrease 2  \
# 0                     9.0                5.0                 9.0
# 1                     9.0                5.0                 9.0
# 2                     9.0                5.0                 9.0
# 3                     9.0                5.0                 9.0
# 4                     9.0                5.0                 9.0
# ...                   ...                ...                 ...
# 39995                 9.0                5.0                 9.0
# 39996                 9.0                5.0                 9.0
# 39997                 9.0                5.0                 9.0
# 39998                 9.0                5.0                 9.0
# 39999                 9.0                5.0                 9.0
#
#        A.5_DikeIncrease 0 A.5_DikeIncrease 1  A.5_DikeIncrease 2  \
# 0                     8.0                1.0                 0.0
# 1                     8.0                1.0                 0.0
# 2                     8.0                1.0                 0.0
# 3                     8.0                1.0                 0.0
# 4                     8.0                1.0                 0.0
# ...                   ...                ...                 ...
# 39995                 8.0                1.0                 0.0
# 39996                 8.0                1.0                 0.0
# 39997                 8.0                1.0                 0.0
# 39998                 8.0                1.0                 0.0
# 39999                 8.0                1.0                 0.0
#
#       EWS_DaysToThreat scenario policy     model
# 0                  1.0      210      2  dikesnet
# 1                  1.0      211      2  dikesnet
# 2                  1.0      212      2  dikesnet
# 3                  1.0      213      2  dikesnet
# 4                  1.0      214      2  dikesnet
# ...                ...      ...    ...       ...
# 39995              1.0    40205      2  dikesnet
# 39996              1.0    40206      2  dikesnet
# 39997              1.0    40207      2  dikesnet
# 39998              1.0    40208      2  dikesnet
# 39999              1.0    40209      2  dikesnet
#
# [40000 rows x 53 columns]

# %%
pd.DataFrame.from_dict(outcomes_loaded)
# Out:
#        A.1 Total Costs  A.1_Expected Number of Deaths  A.2 Total Costs  \
# 0         1.620628e+08                            0.0     2.218915e+08
# 1         1.620628e+08                            0.0     2.218840e+08
# 2         1.620628e+08                            0.0     2.218915e+08
# 3         1.620628e+08                            0.0     2.218915e+08
# 4         1.620628e+08                            0.0     2.218915e+08
# ...                ...                            ...              ...
# 39995     1.620628e+08                            0.0     2.196107e+08
# 39996     1.620628e+08                            0.0     2.197492e+08
# 39997     1.620628e+08                            0.0     2.196107e+08
# 39998     1.620628e+08                            0.0     2.196107e+08
# 39999     1.620628e+08                            0.0     2.196107e+08
#
#        A.2_Expected Number of Deaths  A.3 Total Costs  \
# 0                           0.001504     9.212886e+07
# 1                           0.001497     9.212886e+07
# 2                           0.001504     9.212886e+07
# 3                           0.001504     9.212886e+07
# 4                           0.001504     9.212886e+07
# ...                              ...              ...
# 39995                       0.000331     2.440137e+08
# 39996                       0.000331     2.718614e+08
# 39997                       0.000331     2.389011e+08
# 39998                       0.000331     2.440137e+08
# 39999                       0.000331     2.440137e+08
#
#        A.3_Expected Number of Deaths  A.4 Total Costs  \
# 0                           0.000000     6.216330e+07
# 1                           0.000000     6.216330e+07
# 2                           0.000000     6.216330e+07
# 3                           0.000000     6.216330e+07
# 4                           0.000000     6.216330e+07
# ...                              ...              ...
# 39995                       0.126483     6.216330e+07
# 39996                       0.126483     6.216330e+07
# 39997                       0.126483     6.216330e+07
# 39998                       0.126483     6.216330e+07
# 39999                       0.126483     6.216330e+07
#
#        A.4_Expected Number of Deaths  A.5 Total Costs  \
# 0                                0.0     8.122223e+07
# 1                                0.0     8.122223e+07
# 2                                0.0     8.122223e+07
# 3                                0.0     8.122223e+07
# 4                                0.0     8.122223e+07
# ...                              ...              ...
# 39995                            0.0     8.122223e+07
# 39996                            0.0     8.122223e+07
# 39997                            0.0     8.122223e+07
# 39998                            0.0     8.122223e+07
# 39999                            0.0     8.122223e+07
#
#        A.5_Expected Number of Deaths  RfR Total Costs  \
# 0                                0.0     1.305500e+09
# 1                                0.0     1.305500e+09
# 2                                0.0     1.305500e+09
# 3                                0.0     1.305500e+09
# 4                                0.0     1.305500e+09
# ...                              ...              ...
# 39995                            0.0     1.305500e+09
# 39996                            0.0     1.305500e+09
# 39997                            0.0     1.305500e+09
# 39998                            0.0     1.305500e+09
# 39999                            0.0     1.305500e+09
#
#        Expected Evacuation Costs
# 0                     113.638340
# 1                     113.432413
# 2                     113.638340
# 3                     113.638340
# 4                     113.638340
# ...                          ...
# 39995                5206.967584
# 39996                5206.967584
# 39997                5206.967584
# 39998                5206.967584
# 39999                5206.967584
#
# [40000 rows x 12 columns]

# %%
for y in pd.DataFrame.from_dict(outcomes_loaded).columns.to_list():
    print(y)
# Out:
# A.1 Total Costs
# A.1_Expected Number of Deaths
# A.2 Total Costs
# A.2_Expected Number of Deaths
# A.3 Total Costs
# A.3_Expected Number of Deaths
# A.4 Total Costs
# A.4_Expected Number of Deaths
# A.5 Total Costs
# A.5_Expected Number of Deaths
# RfR Total Costs
# Expected Evacuation Costs

# %% [markdown]
# ### By default, the Sobol sampler calculates second-order interaction effects between each pair of variables.
#
# The SALib analysis returns a dictionary with keys for the different relevant indicators (e.g. S1 and ST for first-order and total effects). The values are in the same order as the names of the problem dictionary, and indicate the fraction of total output variance corresponding to each of the indices.

# %%
for y in pd.DataFrame.from_dict(outcomes_loaded).columns.to_list(): # iterating the columns of dataframe
    Si = sobol.analyze(problem, outcomes_loaded[y], calc_second_order=True,print_to_console=False) # Getting SAlib index for each column in output dataframe

    # Processing the results for plotting the graph
    scores_filtered = {k:Si[k] for k in ['ST','ST_conf','S1','S1_conf']}
    Si_df = pd.DataFrame(scores_filtered, index=problem['names'])

    sns.set_style('white')
    fig, ax = plt.subplots(1
    )

    indices = Si_df[['S1','ST']]
    err = Si_df[['S1_conf','ST_conf']]

    indices.plot.bar(yerr=err.values.T,ax=ax)
    fig.set_size_inches(8,6)
    ax.set_title(str(y))
    ax.figure.tight_layout()
    fig.subplots_adjust(bottom=0.3)
    fig.savefig(f'analysis_figures/salib_uncertainity/{str(y)}_uncertainities_salib_index.png', dpi=300)
    plt.show()
# Out:
# /Users/anmolsoni/anaconda3/envs/epa1361/lib/python3.8/site-packages/SALib/analyze/sobol.py:87: RuntimeWarning: invalid value encountered in true_divide
#   Y = (Y - Y.mean()) / Y.std()
# /Users/anmolsoni/anaconda3/envs/epa1361/lib/python3.8/site-packages/numpy/core/_asarray.py:83: UserWarning: Warning: converting a masked element to nan.
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# ### Interesting Takeaways -
# 1. Total costs and total deaths for each area is influenced majorly by the probability of dike failing in that respective area i.e. A1 Total Costs and Expected number of deaths is influenced by A1_Pfail.
# 2. Except for interestingly, Area 4 - Cortonoever, which is also influenced by dikes failining in A2 and A3, which makes sense as its a downstream town.

# %%
experiments_loaded.columns
# Out:
# Index(['A.0_ID flood wave shape', 'A.1_Bmax', 'A.1_Brate', 'A.1_pfail',
#        'A.2_Bmax', 'A.2_Brate', 'A.2_pfail', 'A.3_Bmax', 'A.3_Brate',
#        'A.3_pfail', 'A.4_Bmax', 'A.4_Brate', 'A.4_pfail', 'A.5_Bmax',
#        'A.5_Brate', 'A.5_pfail', 'discount rate 0', 'discount rate 1',
#        'discount rate 2', '0_RfR 0', '0_RfR 1', '0_RfR 2', '1_RfR 0',
#        '1_RfR 1', '1_RfR 2', '2_RfR 0', '2_RfR 1', '2_RfR 2', '3_RfR 0',
#        '3_RfR 1', '3_RfR 2', '4_RfR 0', '4_RfR 1', '4_RfR 2',
#        'A.1_DikeIncrease 0', 'A.1_DikeIncrease 1', 'A.1_DikeIncrease 2',
#        'A.2_DikeIncrease 0', 'A.2_DikeIncrease 1', 'A.2_DikeIncrease 2',
#        'A.3_DikeIncrease 0', 'A.3_DikeIncrease 1', 'A.3_DikeIncrease 2',
#        'A.4_DikeIncrease 0', 'A.4_DikeIncrease 1', 'A.4_DikeIncrease 2',
#        'A.5_DikeIncrease 0', 'A.5_DikeIncrease 1', 'A.5_DikeIncrease 2',
#        'EWS_DaysToThreat', 'scenario', 'policy', 'model'],
#       dtype='object')

# %%
y = pd.DataFrame.from_dict(outcomes_loaded)
y = y[['A.1 Total Costs','A.1_Expected Number of Deaths','A.2 Total Costs','A.2_Expected Number of Deaths','A.3 Total Costs','A.3_Expected Number of Deaths','A.4 Total Costs','A.5 Total Costs',	'A.5_Expected Number of Deaths','Expected Evacuation Costs']]

# %%
from ema_workbench.analysis import feature_scoring

x = experiments_loaded[['A.0_ID flood wave shape', 'A.1_Bmax', 'A.1_Brate', 'A.1_pfail',
       'A.2_Bmax', 'A.2_Brate', 'A.2_pfail', 'A.3_Bmax', 'A.3_Brate',
       'A.3_pfail', 'A.4_Bmax', 'A.4_Brate', 'A.4_pfail', 'A.5_Bmax',
       'A.5_Brate', 'A.5_pfail', 'discount rate 0', 'discount rate 1',
       'discount rate 2']]
y = pd.DataFrame.from_dict(outcomes_loaded)
y = y[['A.1 Total Costs','A.1_Expected Number of Deaths','A.2 Total Costs','A.2_Expected Number of Deaths','A.3 Total Costs','A.3_Expected Number of Deaths','A.4 Total Costs','A.5 Total Costs',	'A.5_Expected Number of Deaths','Expected Evacuation Costs']]

fig, ax = plt.subplots(figsize=(10,10))
fs = feature_scoring.get_feature_scores_all(x, y)
sns.heatmap(fs, cmap='viridis', annot=True, ax=ax)
ax.figure.tight_layout()
fig.savefig(f'analysis_figures/salib_uncertainity/feature_scores_uncertainities_salib_index.png', dpi=300)
plt.show()

# %% [markdown]
# ### Expected evacuation costs are highly influenced by the probability of A3 Zutphen Dike failing.

# %% [markdown]
# While identifying the uncertainties affecting the outcomes we have aggregated the costs and prioritized the safety by focusing the analysis on number of deaths in each area.

# %% [markdown]
# ## Analysis for identiying policy levers

# %%
# Copy levers from the model defination
print(f'Number of policy levers = {len(dike_model.levers)}')
levers = dike_model.levers
levers = copy.deepcopy(dike_model.levers)

print(f'Number of runs required = N(2K+2) = {1000*(2*31+2)}')

# Set problem for salib by passing all the model levers
problem = get_SALib_problem(levers)
# Out:
# Number of policy levers = 31
# Number of runs required = N(2K+2) = 64000

# %% [markdown]
# `CAUTION`
# > 'UNCOMMENT FOLLOWING CODE WHEN RUNNING FOR THE FIRST TIME - 64K SCENARIOS TOOK ME 48+ HOURS TO RUN'

# %%
# with MultiprocessingEvaluator(dike_model) as evaluator:
#     experiments_sobol, outcomes_sobol = evaluator.perform_experiments(scenarios=1,uncertainty_sampling=LHS, levers_sampling = SOBOL, policies=1000)

# save_results((experiments_sobol, outcomes_sobol), 'data_processed/sensitivty_analysis/sobol_levers_sampling.tar.gz')

# %%
experiments_loaded, outcomes_loaded = load_results('data_processed/sensitivty_analysis/sobol_levers_sampling.tar.gz')
# Out:
# [MainProcess/INFO] results loaded succesfully from /Users/anmolsoni/Documents/Documents – Anmol’s MacBook Air/EPA1361/Assignments/epa_1361/final assignment/sobol_levers_sampling.tar.gz

# %%
for y in pd.DataFrame.from_dict(outcomes_loaded).columns.to_list(): # iterating the columns of dataframe
    Si = sobol.analyze(problem, outcomes_loaded[y], calc_second_order=True,print_to_console=False) # Getting SAlib index for each column in output dataframe

    # Processing the results for plotting the graph
    scores_filtered = {k:Si[k] for k in ['ST','ST_conf','S1','S1_conf']}
    Si_df = pd.DataFrame(scores_filtered, index=problem['names'])

    sns.set_style('white')
    fig, ax = plt.subplots(1)

    indices = Si_df[['S1','ST']]
    err = Si_df[['S1_conf','ST_conf']]

    indices.plot.bar(yerr=err.values.T,ax=ax)
    fig.set_size_inches(8,6)
    ax.set_title(str(y))
    ax.figure.tight_layout()
    fig.subplots_adjust(bottom=0.3)
    fig.savefig(f'analysis_figures/salib_lever/{str(y)}_levers_salib_index.png', dpi=300)
    plt.show()

# %%
experiments_loaded.columns
# Out:
# Index(['A.0_ID flood wave shape', 'A.1_Bmax', 'A.1_Brate', 'A.1_pfail',
#        'A.2_Bmax', 'A.2_Brate', 'A.2_pfail', 'A.3_Bmax', 'A.3_Brate',
#        'A.3_pfail', 'A.4_Bmax', 'A.4_Brate', 'A.4_pfail', 'A.5_Bmax',
#        'A.5_Brate', 'A.5_pfail', 'discount rate 0', 'discount rate 1',
#        'discount rate 2', '0_RfR 0', '0_RfR 1', '0_RfR 2', '1_RfR 0',
#        '1_RfR 1', '1_RfR 2', '2_RfR 0', '2_RfR 1', '2_RfR 2', '3_RfR 0',
#        '3_RfR 1', '3_RfR 2', '4_RfR 0', '4_RfR 1', '4_RfR 2',
#        'A.1_DikeIncrease 0', 'A.1_DikeIncrease 1', 'A.1_DikeIncrease 2',
#        'A.2_DikeIncrease 0', 'A.2_DikeIncrease 1', 'A.2_DikeIncrease 2',
#        'A.3_DikeIncrease 0', 'A.3_DikeIncrease 1', 'A.3_DikeIncrease 2',
#        'A.4_DikeIncrease 0', 'A.4_DikeIncrease 1', 'A.4_DikeIncrease 2',
#        'A.5_DikeIncrease 0', 'A.5_DikeIncrease 1', 'A.5_DikeIncrease 2',
#        'EWS_DaysToThreat', 'scenario', 'policy', 'model'],
#       dtype='object')

# %%
experiments_loaded[['A.0_ID flood wave shape', 'A.1_Bmax', 'A.1_Brate', 'A.2_Brate', 'A.3_Brate', 'A.4_Brate',
       'A.5_Brate', 'discount rate 0', 'discount rate 1',
       'discount rate 2', '0_RfR 0', '0_RfR 1', '0_RfR 2', '1_RfR 0',
       '1_RfR 1', '1_RfR 2', '2_RfR 0', '2_RfR 1', '2_RfR 2', '3_RfR 0',
       '3_RfR 1', '3_RfR 2', '4_RfR 0', '4_RfR 1', '4_RfR 2',
       'A.1_DikeIncrease 0', 'A.1_DikeIncrease 1', 'A.1_DikeIncrease 2',
       'A.2_DikeIncrease 0', 'A.2_DikeIncrease 1', 'A.2_DikeIncrease 2',
       'A.3_DikeIncrease 0', 'A.3_DikeIncrease 1', 'A.3_DikeIncrease 2',
       'A.4_DikeIncrease 0', 'A.4_DikeIncrease 1', 'A.4_DikeIncrease 2',
       'A.5_DikeIncrease 0', 'A.5_DikeIncrease 1', 'A.5_DikeIncrease 2',
       'EWS_DaysToThreat', 'scenario', 'model']]

# %%
from ema_workbench.analysis import feature_scoring
# Only keep levers for feature scoring
x = experiments_loaded[['0_RfR 0', '0_RfR 1', '0_RfR 2', '1_RfR 0',
       '1_RfR 1', '1_RfR 2', '2_RfR 0', '2_RfR 1', '2_RfR 2', '3_RfR 0',
       '3_RfR 1', '3_RfR 2', '4_RfR 0', '4_RfR 1', '4_RfR 2',
       'A.1_DikeIncrease 0', 'A.1_DikeIncrease 1', 'A.1_DikeIncrease 2',
       'A.2_DikeIncrease 0', 'A.2_DikeIncrease 1', 'A.2_DikeIncrease 2',
       'A.3_DikeIncrease 0', 'A.3_DikeIncrease 1', 'A.3_DikeIncrease 2',
       'A.4_DikeIncrease 0', 'A.4_DikeIncrease 1', 'A.4_DikeIncrease 2',
       'A.5_DikeIncrease 0', 'A.5_DikeIncrease 1', 'A.5_DikeIncrease 2',
       'EWS_DaysToThreat']]
y = outcomes_loaded

fig, ax = plt.subplots(figsize=(10,10))
fs = feature_scoring.get_feature_scores_all(x, y)
sns.heatmap(fs, cmap='viridis', annot=True, ax=ax)
ax.figure.tight_layout()
fig.savefig(f'analysis_figures/salib_lever/feature_scores_levers_salib_index.png', dpi=300)
plt.show()

# %% [markdown]
# Observation: Increasing dike is the most effective lever for reducing death in the province. RFR has some influence on results but can not be used as stand alone policy.
